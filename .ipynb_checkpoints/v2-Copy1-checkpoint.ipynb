# %%
import sounddevice as sd
# Constants
RATE = 16000
CHANNELS = 1

def get_default_output_device_name():
    devices = sd.query_devices()
    devices_string = str(devices)
    devices_list = devices_string.split('\n')
    row_number = find_element_with_symbol(devices_list, '<')
    device_name=devices[int(row_number)]['name']
    if device_name:
        return device_name
    else:
        return None
        
def record_system_audio(duration):
    default_output_device_name = get_default_output_device_name()
    device_info = sd.query_devices()
    # Find the loopback audio device
    system_audio_device = None
    for device in device_info:
        if device['name'] == default_output_device_name:
            system_audio_device = device
            break
    if system_audio_device:
        #channels = system_audio_device['max_output_channels']
        channels=CHANNELS
        print("channels",channels)
        #fs = system_audio_device['default_samplerate']
        fs=RATE
        print("samplerate",fs)
        frames = int(duration * fs)
        audio_data = sd.rec(frames=frames, samplerate=fs, channels=channels, dtype='float32')
        sd.wait()
        return np.squeeze(audio_data)
    else:
        print("System audio device not found.")
        return None

# %%
# Example usage
duration = 5  # Recording duration in seconds
audio_data = record_system_audio(duration)
if audio_data is not None:
    # Process or save the recorded audio data
    print(f"Recorded system audio with shape: {audio_data.shape}")
# Out:
# channels 1
# samplerate 16000
# Recorded system audio with shape: (80000,)

# %%
def save_to_byte_stream(audio_data):
    with io.BytesIO() as byte_stream:
        with sf.SoundFile(byte_stream, 'w', samplerate=RATE, channels=CHANNELS, format='WAV', subtype='PCM_16') as wav_file:
            wav_file.write(audio_data)
        byte_stream.seek(0)
        audio_segment = AudioSegment.from_file(byte_stream, format="wav")
    return audio_segment

# %%
def play_audio(audio_segment):
    print("Playing audio...")
    audio_data = np.array(audio_segment.get_array_of_samples(), dtype=np.int16)
    sd.play(audio_data, samplerate=RATE)
    sd.wait()

# %%
audio_segment = save_to_byte_stream(audio_data)
play_audio(audio_segment)

# %%
# Out:
# Playing audio...

# %% [markdown]
# # Updated

# %%
import sounddevice as sd

# %%
devices = sd.query_devices()

# %%
devices
# Out:
#    0 Microsoft Sound Mapper - Input, MME (2 in, 0 out)
# >  1 Headset Microphone (Jabra EVOLV, MME (2 in, 0 out)
#    2 Microphone (Razer Seiren X), MME (2 in, 0 out)
#    3 Microphone Array (Intel® Smart , MME (2 in, 0 out)
#    4 Microsoft Sound Mapper - Output, MME (0 in, 2 out)
# <  5 Speakers (Realtek(R) Audio), MME (0 in, 2 out)
#    6 Speakers (Razer Seiren X), MME (0 in, 2 out)
#    7 LG ULTRAGEAR (NVIDIA High Defin, MME (0 in, 2 out)
#    8 Headset Earphone (Jabra EVOLVE , MME (0 in, 2 out)
#    9 Primary Sound Capture Driver, Windows DirectSound (2 in, 0 out)
#   10 Headset Microphone (Jabra EVOLVE 20 MS), Windows DirectSound (2 in, 0 out)
#   11 Microphone (Razer Seiren X), Windows DirectSound (2 in, 0 out)
#   12 Microphone Array (Intel® Smart Sound Technology for Digital Microphones), Windows DirectSound (2 in, 0 out)
#   13 Primary Sound Driver, Windows DirectSound (0 in, 2 out)
#   14 Speakers (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#   15 Speakers (Razer Seiren X), Windows DirectSound (0 in, 2 out)
#   16 LG ULTRAGEAR (NVIDIA High Definition Audio), Windows DirectSound (0 in, 2 out)
#   17 Headset Earphone (Jabra EVOLVE 20 MS), Windows DirectSound (0 in, 2 out)
#   18 Speakers (Razer Seiren X), Windows WASAPI (0 in, 2 out)
#   19 LG ULTRAGEAR (NVIDIA High Definition Audio), Windows WASAPI (0 in, 2 out)
#   20 Headset Earphone (Jabra EVOLVE 20 MS), Windows WASAPI (0 in, 2 out)
#   21 Speakers (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#   22 Headset Microphone (Jabra EVOLVE 20 MS), Windows WASAPI (1 in, 0 out)
#   23 Microphone (Razer Seiren X), Windows WASAPI (2 in, 0 out)
#   24 Microphone Array (Intel® Smart Sound Technology for Digital Microphones), Windows WASAPI (2 in, 0 out)
#   25 Output (NVIDIA High Definition Audio), Windows WDM-KS (0 in, 2 out)
#   26 Headphones (Realtek HD Audio 2nd output), Windows WDM-KS (0 in, 2 out)
#   27 Stereo Mix (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   28 Speakers (Realtek HD Audio output with SST), Windows WDM-KS (0 in, 2 out)
#   29 Microphone (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#   30 Microphone Array 1 (), Windows WDM-KS (2 in, 0 out)
#   31 Microphone Array 2 (), Windows WDM-KS (2 in, 0 out)
#   32 Microphone Array 3 (), Windows WDM-KS (4 in, 0 out)
#   33 Headset Microphone (Jabra EVOLVE 20 MS), Windows WDM-KS (1 in, 0 out)
#   34 Headset Earphone (Jabra EVOLVE 20 MS), Windows WDM-KS (0 in, 2 out)
#   35 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(WH-1000XM4)), Windows WDM-KS (0 in, 1 out)
#   36 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(WH-1000XM4)), Windows WDM-KS (1 in, 0 out)
#   37 Speakers (), Windows WDM-KS (0 in, 2 out)
#   38 Headphones (), Windows WDM-KS (0 in, 2 out)
#   39 Output 1 (Razer Seiren X), Windows WDM-KS (0 in, 2 out)
#   40 Output 2 (Razer Seiren X), Windows WDM-KS (0 in, 8 out)
#   41 Input (Razer Seiren X), Windows WDM-KS (2 in, 0 out)
#   42 Speakers (Razer Seiren X), Windows WDM-KS (0 in, 2 out)
#   43 Microphone 1 (Razer Seiren X), Windows WDM-KS (2 in, 0 out)
#   44 Microphone 2 (Razer Seiren X), Windows WDM-KS (2 in, 0 out)

# %%
import sounddevice as sd
import numpy as np
# Constants
RATE = 16000
CHANNELS = 1
def get_default_output_device_name():
    devices = sd.query_devices()
    devices_string = str(devices)
    devices_list = devices_string.split('\n')
    row_number = find_element_with_symbol(devices_list, '<')
    device_name=devices[int(row_number)]['name']
    if device_name:
        return device_name
    else:
        return None

def get_default_input_device_name():
    devices = sd.query_devices()
    devices_string = str(devices)
    devices_list = devices_string.split('\n')
    row_number = find_element_with_symbol(devices_list, '>')
    device_name=devices[int(row_number)]['name']
    if device_name:
        return device_name
    else:
        return None


def record_system_audio(duration):
    default_output_device_name = get_default_output_device_name()
    device_info = sd.query_devices()
    # Find the loopback audio device
    system_audio_device = None
    for device in device_info:
        if device['name'] == default_output_device_name:
            system_audio_device = device
            break
    if system_audio_device:
        #channels = system_audio_device['max_output_channels']
        #fs = system_audio_device['default_samplerate']
        channels=CHANNELS
        fs=RATE
        frames = int(duration * fs)

        audio_data = sd.playrec(np.zeros((frames, channels)), samplerate=fs, channels=channels, dtype='float32')
        sd.wait()
        return np.squeeze(audio_data)
    else:
        print("System audio device not found.")
        return None

# %%
# Example usage
duration = 5  # Recording duration in seconds
audio_data = record_system_audio(duration)
if audio_data is not None:
    # Process or save the recorded audio data
    print(f"Recorded system audio with shape: {audio_data.shape}")
# Out:
# Recorded system audio with shape: (80000,)

# %%
audio_segment = save_to_byte_stream(audio_data)
play_audio(audio_segment)
# Out:
# Playing audio...
