# %%
#!pip install keyboard

# %%
# Out:
# Voice detected
# Silence detected
# Playing audio...
# Voice detected
# Silence detected
# Playing audio...
# Voice detected
# Silence detected
# Playing audio...
# Voice detected
# Silence detected
# Playing audio...
# Voice detected
# Silence detected
# Playing audio...
# Program stopped.
# Voice detected
# Silence detected
# Playing audio...
# Voice detected
# Silence detected
# Playing audio...
